# %% [markdown]
# <a href="https://colab.research.google.com/github/ibonetc/DeepLearning_Salud/blob/main/GAN_UNET_RetinaExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problema de segmentación en Retina
#
# Las estructuras exhibidas por la vasculatura retiniana infieren información crítica sobre una amplia gama de patologías retinianas como la prematuridad (RoP), la retinopatía diabética (DR), el glaucoma, la hipertensión y la degeneración macular relacionada con la edad (AMD). Estas patologías se encuentran entre las principales causas de ceguera. La segmentación precisa de la vasculatura retiniana es importante para varios procedimientos diagnósticos y terapéuticos oftalmológicos.
#
# Vamos a usar una base de datos DRIVE(Digital Retinal Images for Vessel Extraction) que puede ver en: https://drive.grand-challenge.org/.
#
# La base de datos DRIVE se desarrolló con la idea de permitir estudios comparativos sobre la segmentación de los vasos sanguíneos en las imágenes de la retina.
#
# La segmentación de los vasos de la retina y la delimitación de los atributos morfológicos de los vasos sanguíneos de la retina, como la longitud, la anchura, la tortuosidad, los patrones de ramificación y los ángulos, se utilizan para el diagnóstico, la detección, el tratamiento y la evaluación de diversas enfermedades cardiovasculares y oftalmológicas, como la diabetes, la hipertensión y la arteriosclerosis. y neovascularización coroidea.
#
# La detección automática y el análisis de la vasculatura pueden ayudar en la implementación de programas de detección para la retinopatía diabética, pueden ayudar a la investigación sobre la relación entre la tortuosidad de los vasos y la retinopatía hipertensiva, la medición del diámetro de los vasos en relación con el diagnóstico de hipertensión y la cirugía láser asistida por computadora.
#
# La generación automática de mapas retinianos y la extracción de puntos de ramificación se han utilizado para el registro de imágenes temporales o multimodales y la síntesis de mosaicos de imágenes retinianas. Además, el árbol vascular de la retina es único para cada individuo y puede usarse para la identificación biométrica.

# %% [markdown]
# ## Carga de datos con datagen
#
# Las imágenes originales de DRIVE tienen un tamaño de 565 × 584. Se redimensionaron a 512 × 512
#
# Teniendo en cuenta que nuestro conjunto de entrenamiento es bastante pequeño, en este caso es útil utilizar técnicas de aumento de datos, como las vistas anteriormente, para mejorar el tamaño de nuestros datos de entrenamiento. Para ello, utilizaremos la clase ImageDataGenerator de keras. Le permite configurar la preparación y el aumento de la imagen.
#
# Para preparar nuestros datos para el entrenamiento, primero debemos reescalarlos dentro del intervalo [0, 1], para lo que vamos a divir las imágenes por 255.
#
# Al aumentar nuestros datos, podemos usar rotaciones aleatorias. El rango de grados de estas rotaciones aleatorias se puede especificar en el generador de datos. Esto haría que la rotación de nuestro modelo fuera invariable, ya que el modelo vería imágenes de diferentes orientaciones. Además, podemos utilizar desplazamientos aleatorios horizontales y verticales como técnica de aumento. Al entrenar nuestro modelo en imágenes con diferentes desplazamientos verticales y/u horizontales, podemos hacer que nuestro modelo sea invariante traslacional. El zoom es otra técnica de aumento que podemos utilizar. Eso haría que la escala de nuestro modelo fuera invariable. Podemos configurar las técnicas de aumento y preparación de datos de imagen anteriores como se muestra a continuación.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Input, Dropout, Flatten, Conv2D,MaxPooling2D, Dense, Activation,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import numpy as np
from tensorflow.keras.utils import plot_model

# %%
# !unzip '/content/drive/MyDrive/HealthData/DriveJPG.zip'

# %%
pathImages='/content/DriveJPG/train/image'
pathMask='/content/DriveJPG/train/mask'

# %%
import os
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

# %%
input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_38 (Conv2D)             (None, 512, 512, 64  1792        ['input_4[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 512, 512, 64  256        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 512, 512, 64  36928       ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 512, 512, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 256, 256, 64  0          ['activation_37[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_8[0][0]']
#                                 8)
#
#  batch_normalization_38 (BatchN  (None, 256, 256, 12  512        ['conv2d_40[0][0]']
#  ormalization)                  8)
#
#  activation_38 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_38[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 12  147584      ['activation_38[0][0]']
#                                 8)
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 12  512        ['conv2d_41[0][0]']
#  ormalization)                  8)
#
#  activation_39 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_39[0][0]']
#                                 8)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_39[0][0]']
#                                 8)
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_9[0][0]']
#                                 6)
#
#  batch_normalization_40 (BatchN  (None, 128, 128, 25  1024       ['conv2d_42[0][0]']
#  ormalization)                  6)
#
#  activation_40 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_40[0][0]']
#                                 6)
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 25  590080      ['activation_40[0][0]']
#                                 6)
#
#  batch_normalization_41 (BatchN  (None, 128, 128, 25  1024       ['conv2d_43[0][0]']
#  ormalization)                  6)
#
#  activation_41 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_41[0][0]']
#                                 6)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 256)  0          ['activation_41[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_10[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_43[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 512)  0          ['activation_43[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_11[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_44[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  activation_45 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_45[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_8[0][0]',
#                                 )                                 'activation_43[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_8[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_47[0][0]']
#  spose)                         6)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_9[0][0]',
#                                 2)                                'activation_41[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_9[0][0]']
#                                 6)
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 25  1024       ['conv2d_50[0][0]']
#  ormalization)                  6)
#
#  activation_48 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_48[0][0]']
#                                 6)
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 25  590080      ['activation_48[0][0]']
#                                 6)
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 25  1024       ['conv2d_51[0][0]']
#  ormalization)                  6)
#
#  activation_49 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_49[0][0]']
#                                 6)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_49[0][0]']
#  nspose)                        8)
#
#  concatenate_10 (Concatenate)   (None, 256, 256, 25  0           ['conv2d_transpose_10[0][0]',
#                                 6)                                'activation_39[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_10[0][0]']
#                                 8)
#
#  batch_normalization_50 (BatchN  (None, 256, 256, 12  512        ['conv2d_52[0][0]']
#  ormalization)                  8)
#
#  activation_50 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_50[0][0]']
#                                 8)
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 12  147584      ['activation_50[0][0]']
#                                 8)
#
#  batch_normalization_51 (BatchN  (None, 256, 256, 12  512        ['conv2d_53[0][0]']
#  ormalization)                  8)
#
#  activation_51 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_51[0][0]']
#                                 8)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_51[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 12  0           ['conv2d_transpose_11[0][0]',
#                                 8)                                'activation_37[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 512, 512, 64  256        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  activation_52 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 512, 512, 64  36928       ['activation_52[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 512, 512, 64  256        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  activation_53 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 512, 512, 1)  65          ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# Métricas

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# Entrenar el modelo

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.jpg")))
    y = sorted(glob(os.path.join(path, "mask", "*.jpg")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

# %%
""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 100
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "data.csv")

# %%
""" Dataset """
dataset_path = "/content/DriveJPG"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

# %%
train_path='/content/DriveJPG/train'
valid_path='/content/DriveJPG/test'

# %%
train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

# %%
train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)
train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

# %%
model = build_unet((H, W, 3))
model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_76 (Conv2D)             (None, 512, 512, 64  1792        ['input_6[0][0]']
#                                 )
#
#  batch_normalization_72 (BatchN  (None, 512, 512, 64  256        ['conv2d_76[0][0]']
#  ormalization)                  )
#
#  activation_72 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_72[0][0]']
#                                 )
#
#  conv2d_77 (Conv2D)             (None, 512, 512, 64  36928       ['activation_72[0][0]']
#                                 )
#
#  batch_normalization_73 (BatchN  (None, 512, 512, 64  256        ['conv2d_77[0][0]']
#  ormalization)                  )
#
#  activation_73 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_73[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 256, 256, 64  0          ['activation_73[0][0]']
#  )                              )
#
#  conv2d_78 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_16[0][0]']
#                                 8)
#
#  batch_normalization_74 (BatchN  (None, 256, 256, 12  512        ['conv2d_78[0][0]']
#  ormalization)                  8)
#
#  activation_74 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_74[0][0]']
#                                 8)
#
#  conv2d_79 (Conv2D)             (None, 256, 256, 12  147584      ['activation_74[0][0]']
#                                 8)
#
#  batch_normalization_75 (BatchN  (None, 256, 256, 12  512        ['conv2d_79[0][0]']
#  ormalization)                  8)
#
#  activation_75 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_75[0][0]']
#                                 8)
#
#  max_pooling2d_17 (MaxPooling2D  (None, 128, 128, 12  0          ['activation_75[0][0]']
#  )                              8)
#
#  conv2d_80 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_17[0][0]']
#                                 6)
#
#  batch_normalization_76 (BatchN  (None, 128, 128, 25  1024       ['conv2d_80[0][0]']
#  ormalization)                  6)
#
#  activation_76 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_76[0][0]']
#                                 6)
#
#  conv2d_81 (Conv2D)             (None, 128, 128, 25  590080      ['activation_76[0][0]']
#                                 6)
#
#  batch_normalization_77 (BatchN  (None, 128, 128, 25  1024       ['conv2d_81[0][0]']
#  ormalization)                  6)
#
#  activation_77 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_77[0][0]']
#                                 6)
#
#  max_pooling2d_18 (MaxPooling2D  (None, 64, 64, 256)  0          ['activation_77[0][0]']
#  )
#
#  conv2d_82 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_18[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_78[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_79[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 32, 32, 512)  0          ['activation_79[0][0]']
#  )
#
#  conv2d_84 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_19[0][0]']
#                                 )
#
#  batch_normalization_80 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_84[0][0]']
#  ormalization)                  )
#
#  activation_80 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_80[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_80[0][0]']
#                                 )
#
#  batch_normalization_81 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_85[0][0]']
#  ormalization)                  )
#
#  activation_81 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_81[0][0]']
#                                 )
#
#  conv2d_transpose_16 (Conv2DTra  (None, 64, 64, 512)  2097664    ['activation_81[0][0]']
#  nspose)
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 1024  0           ['conv2d_transpose_16[0][0]',
#                                 )                                 'activation_79[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_16[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_83[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 128, 128, 25  524544     ['activation_83[0][0]']
#  nspose)                        6)
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 51  0           ['conv2d_transpose_17[0][0]',
#                                 2)                                'activation_77[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_17[0][0]']
#                                 6)
#
#  batch_normalization_84 (BatchN  (None, 128, 128, 25  1024       ['conv2d_88[0][0]']
#  ormalization)                  6)
#
#  activation_84 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_84[0][0]']
#                                 6)
#
#  conv2d_89 (Conv2D)             (None, 128, 128, 25  590080      ['activation_84[0][0]']
#                                 6)
#
#  batch_normalization_85 (BatchN  (None, 128, 128, 25  1024       ['conv2d_89[0][0]']
#  ormalization)                  6)
#
#  activation_85 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_85[0][0]']
#                                 6)
#
#  conv2d_transpose_18 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_85[0][0]']
#  nspose)                        8)
#
#  concatenate_18 (Concatenate)   (None, 256, 256, 25  0           ['conv2d_transpose_18[0][0]',
#                                 6)                                'activation_75[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_18[0][0]']
#                                 8)
#
#  batch_normalization_86 (BatchN  (None, 256, 256, 12  512        ['conv2d_90[0][0]']
#  ormalization)                  8)
#
#  activation_86 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_86[0][0]']
#                                 8)
#
#  conv2d_91 (Conv2D)             (None, 256, 256, 12  147584      ['activation_86[0][0]']
#                                 8)
#
#  batch_normalization_87 (BatchN  (None, 256, 256, 12  512        ['conv2d_91[0][0]']
#  ormalization)                  8)
#
#  activation_87 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_87[0][0]']
#                                 8)
#
#  conv2d_transpose_19 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_87[0][0]']
#  nspose)                        )
#
#  concatenate_19 (Concatenate)   (None, 512, 512, 12  0           ['conv2d_transpose_19[0][0]',
#                                 8)                                'activation_73[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_19[0][0]']
#                                 )
#
#  batch_normalization_88 (BatchN  (None, 512, 512, 64  256        ['conv2d_92[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_88[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 512, 512, 64  36928       ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 512, 512, 64  256        ['conv2d_93[0][0]']
#  ormalization)                  )
#
#  activation_89 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_89[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 512, 512, 1)  65          ['activation_89[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)

# %%
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.jpg")))
    y = sorted(glob(os.path.join(path, "mask", "*.jpg")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %% [markdown]
# Cargar el modelo entrenado y crear carpeta para resultados.

# %%
create_dir("results")

""" Load the model """
with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
    model = tf.keras.models.load_model("files/model.h5")

# %% [markdown]
# Cargar los datos de prueba

# %%
dataset_path = '/content/DriveJPG/test'
test_x, test_y = load_data(dataset_path)

# %% [markdown]
# Hacer predicción

# %%
import pandas as pd
from tqdm import tqdm

# %%
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])
# Out:
# 100%|██████████| 20/20 [00:13<00:00,  1.52it/s]

# %%
score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score.csv")
# Out:
# Accuracy: 0.33384
# F1: 0.05961
# Jaccard: 0.03074
# Recall: 0.63641
# Precision: 0.03135
